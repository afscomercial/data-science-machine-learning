# %% [markdown]
# <a href="https://colab.research.google.com/github/afscomercial/data-science-machine-learning/blob/main/introToPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('customers.csv')

# %%
df.shape
# Out:
# (13, 6)

# %%
df.columns
# Out:
# Index(['id', 'cust_name', 'num_products', 'province', 'len_relationship',
#        'cust_category'],
#       dtype='object')

# %%
df.head(2)
# Out:
#      id       cust_name  num_products province  len_relationship  \
# 0  1001  Johnny Awesome             3       ON                 1
# 1  1002      Bob Marley             4       ON                 1
#
#       cust_category
# 0            wealth
# 1  personal_banking

# %%
df2 = df.rename(columns = {'id':'cust_id'})
df2.head(2)
# Out:
#    cust_id       cust_name  num_products province  len_relationship  \
# 0     1001  Johnny Awesome             3       ON                 1
# 1     1002      Bob Marley             4       ON                 1
#
#       cust_category
# 0            wealth
# 1  personal_banking

# %%
df2.set_index('cust_id', inplace=True)
df2.head(2)
# Out:
#               cust_name  num_products province  len_relationship  \
# cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 1001 to 1475
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cust_name         13 non-null     object
#  1   num_products      13 non-null     int64
#  2   province          13 non-null     object
#  3   len_relationship  13 non-null     int64
#  4   cust_category     13 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 624.0+ bytes

# %%
df2.describe()
# Out:
#        num_products  len_relationship
# count     13.000000         13.000000
# mean       3.153846          3.461538
# std        1.344504          2.366974
# min        1.000000          1.000000
# 25%        2.000000          2.000000
# 50%        3.000000          3.000000
# 75%        4.000000          4.000000
# max        5.000000         10.000000

# %%
df2.axes

# axis = 0 is for rows
# axis = 1 is for columns
# Out:
# [Index([1001, 1002, 1004, 1101, 1006, 1014, 1254, 1285, 1354, 1005, 1008, 1585,
#         1475],
#        dtype='int64', name='cust_id'),
#  Index(['cust_name', 'num_products', 'province', 'len_relationship',
#         'cust_category'],
#        dtype='object')]

# %%
df2.sort_index(axis=0, ascending=True)
# Out:
#                   cust_name  num_products province  len_relationship  \
# cust_id
# 1001         Johnny Awesome             3       ON                 1
# 1002             Bob Marley             4       ON                 1
# 1004           Taylor Swift             2       AB                 2
# 1005     Mariah Anita Smith             2       BC                 3
# 1006          Stephen Smith             5       ON                 4
# 1008         Robert Optimus             3       MB                10
# 1014          Delilah Avery             2       AB                 3
# 1101             James Dean             3       BC                 3
# 1254           Johnson Cory             1       AB                 4
# 1285             Maria Alva             5       ON                 2
# 1354           Jessica Fast             4       BC                 5
# 1475      Stephanie Element             2       ON                 5
# ...

# %%
df2[['cust_name', 'num_products']]
# Out:
#                   cust_name  num_products
# cust_id
# 1001         Johnny Awesome             3
# 1002             Bob Marley             4
# 1004           Taylor Swift             2
# 1101             James Dean             3
# 1006          Stephen Smith             5
# 1014          Delilah Avery             2
# 1254           Johnson Cory             1
# 1285             Maria Alva             5
# 1354           Jessica Fast             4
# 1005     Mariah Anita Smith             2
# 1008         Robert Optimus             3
# 1585           Steven Prime             5
# 1475      Stephanie Element             2

# %%
#df.loc: label based indexing
#df.iloc: integer based indexing

# %%
df2.iloc[1:4]
# Out:
#             cust_name  num_products province  len_relationship  \
# cust_id
# 1002       Bob Marley             4       ON                 1
# 1004     Taylor Swift             2       AB                 2
# 1101       James Dean             3       BC                 3
#
#             cust_category
# cust_id
# 1002     personal_banking
# 1004                  hnw
# 1101               wealth

# %%
df2.iloc[1:4, 1:3]
# Out:
#          num_products province
# cust_id
# 1002                4       ON
# 1004                2       AB
# 1101                3       BC

# %%
#df2 = df

# %%
df2.head(2)
# Out:
#               cust_name  num_products province  len_relationship  \
# cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking

# %%
#find the cust_category of bob marley
df2[df2['cust_name'] == 'Bob Marley']['cust_category']
# Out:
# cust_id
# 1002    personal_banking
# Name: cust_category, dtype: object

# %%
# find all the customers belonging to alberta
df2[df2['province'] == 'AB']
# Out:
#              cust_name  num_products province  len_relationship  \
# cust_id
# 1004      Taylor Swift             2       AB                 2
# 1014     Delilah Avery             2       AB                 3
# 1254      Johnson Cory             1       AB                 4
# 1585      Steven Prime             5       AB                 2
#
#             cust_category
# cust_id
# 1004                  hnw
# 1014     personal_banking
# 1254                  hnw
# 1585               wealth

# %%
# which customers belong to either Ontario or British Columbia
df2[(df2['province'] == 'ON') | (df2['province'] == 'BC')]
# Out:
#                   cust_name  num_products province  len_relationship  \
# cust_id
# 1001         Johnny Awesome             3       ON                 1
# 1002             Bob Marley             4       ON                 1
# 1101             James Dean             3       BC                 3
# 1006          Stephen Smith             5       ON                 4
# 1285             Maria Alva             5       ON                 2
# 1354           Jessica Fast             4       BC                 5
# 1005     Mariah Anita Smith             2       BC                 3
# 1475      Stephanie Element             2       ON                 5
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking
# 1101               wealth
# 1006                  hnw
# 1285               wealth
# 1354     personal_banking
# 1005     personal_banking
# 1475     personal_banking

# %%
# which customers belong to either Ontario or British Columbia using isin()
df2[df2['province'].isin(['ON', 'BC'])]
# Out:
#                   cust_name  num_products province  len_relationship  \
# cust_id
# 1001         Johnny Awesome             3       ON                 1
# 1002             Bob Marley             4       ON                 1
# 1101             James Dean             3       BC                 3
# 1006          Stephen Smith             5       ON                 4
# 1285             Maria Alva             5       ON                 2
# 1354           Jessica Fast             4       BC                 5
# 1005     Mariah Anita Smith             2       BC                 3
# 1475      Stephanie Element             2       ON                 5
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking
# 1101               wealth
# 1006                  hnw
# 1285               wealth
# 1354     personal_banking
# 1005     personal_banking
# 1475     personal_banking

# %%
# which are the distinct values of NumProducts in this dataset?
df2['num_products'].unique()
# Out:
# array([3, 4, 2, 5, 1])

# %%
# customers who have more than 2 products
df2[df2['num_products'] > 2]
# Out:
#               cust_name  num_products province  len_relationship  \
# cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1002         Bob Marley             4       ON                 1
# 1101         James Dean             3       BC                 3
# 1006      Stephen Smith             5       ON                 4
# 1285         Maria Alva             5       ON                 2
# 1354       Jessica Fast             4       BC                 5
# 1008     Robert Optimus             3       MB                10
# 1585       Steven Prime             5       AB                 2
#
#             cust_category
# cust_id
# 1001               wealth
# 1002     personal_banking
# 1101               wealth
# 1006                  hnw
# 1285               wealth
# 1354     personal_banking
# 1008                  hnw
# 1585               wealth

# %%
# which customers have numOfProducts, other than 2 or 3
df2[~df2['num_products'].isin([2, 3])]
# Out:
#              cust_name  num_products province  len_relationship  \
# cust_id
# 1002        Bob Marley             4       ON                 1
# 1006     Stephen Smith             5       ON                 4
# 1254      Johnson Cory             1       AB                 4
# 1285        Maria Alva             5       ON                 2
# 1354      Jessica Fast             4       BC                 5
# 1585      Steven Prime             5       AB                 2
#
#             cust_category
# cust_id
# 1002     personal_banking
# 1006                  hnw
# 1254                  hnw
# 1285               wealth
# 1354     personal_banking
# 1585               wealth

# %%
# customers whose names start with j
df2[df2['cust_name'].str.startswith('J')]
# Out:
#               cust_name  num_products province  len_relationship  \
# cust_id
# 1001     Johnny Awesome             3       ON                 1
# 1101         James Dean             3       BC                 3
# 1254       Johnson Cory             1       AB                 4
# 1354       Jessica Fast             4       BC                 5
#
#             cust_category
# cust_id
# 1001               wealth
# 1101               wealth
# 1254                  hnw
# 1354     personal_banking

# %%
# customers whose names have lowercase 'm'
df2[df2['cust_name'].str.contains('m')]
# Out:
#                   cust_name  num_products province  len_relationship  \
# cust_id
# 1001         Johnny Awesome             3       ON                 1
# 1101             James Dean             3       BC                 3
# 1006          Stephen Smith             5       ON                 4
# 1005     Mariah Anita Smith             2       BC                 3
# 1008         Robert Optimus             3       MB                10
# 1585           Steven Prime             5       AB                 2
# 1475      Stephanie Element             2       ON                 5
#
#             cust_category
# cust_id
# 1001               wealth
# 1101               wealth
# 1006                  hnw
# 1005     personal_banking
# 1008                  hnw
# 1585               wealth
# 1475     personal_banking

# %%
# which customer has the longest relationship with the bank
df2[df2['len_relationship'] == df2['len_relationship'].max()]
# Out:
#               cust_name  num_products province  len_relationship cust_category
# cust_id
# 1008     Robert Optimus             3       MB                10           hnw

# %%
tran_df = pd.read_csv('3_transactions.csv')

# %%
tran_df.head()
# Out:
#    id  customer_id txn_type  txn_total
# 0   1         1001    Debit     165.78
# 1   2         1001   Credit      42.10
# 2   4         1001   Credit     103.03
# 3   5         1001   Credit      56.60
# 4   6         1002    Debit     214.34

# %%
merged_df = pd.merge(left = tran_df,
             right = df2,
             left_on = 'customer_id',
             right_on = 'cust_id',
             right_index = True)

# %%
merged_df.head()
# Out:
#    id  customer_id txn_type  txn_total       cust_name  num_products province  \
# 0   1         1001    Debit     165.78  Johnny Awesome             3       ON
# 1   2         1001   Credit      42.10  Johnny Awesome             3       ON
# 2   4         1001   Credit     103.03  Johnny Awesome             3       ON
# 3   5         1001   Credit      56.60  Johnny Awesome             3       ON
# 4   6         1002    Debit     214.34      Bob Marley             4       ON
#
#    len_relationship     cust_category
# 0                 1            wealth
# 1                 1            wealth
# 2                 1            wealth
# 3                 1            wealth
# 4                 1  personal_banking

# %%
merged_df.shape
# Out:
# (34, 9)

# %%
merged_df.to_csv('merged_df.csv') #if path is not specified, it will be saved in the same path as this notebook.

# %%
merged_df = pd.merge(left = tran_df,
             right = df2,
             left_on = 'customer_id',
             right_on = 'cust_id',
             right_index = False)

# %%
merged_df.head()
# Out:
#    id  customer_id txn_type  txn_total       cust_name  num_products province  \
# 0   1         1001    Debit     165.78  Johnny Awesome             3       ON
# 1   2         1001   Credit      42.10  Johnny Awesome             3       ON
# 2   4         1001   Credit     103.03  Johnny Awesome             3       ON
# 3   5         1001   Credit      56.60  Johnny Awesome             3       ON
# 4   6         1002    Debit     214.34      Bob Marley             4       ON
#
#    len_relationship     cust_category
# 0                 1            wealth
# 1                 1            wealth
# 2                 1            wealth
# 3                 1            wealth
# 4                 1  personal_banking

# %%
merged_df.to_csv('merged_df2.csv') #if path is not specified, it will be saved in the same path as this notebook.

# %%
# Groupby:
